# %%
import openai, os

# %%
from openai import OpenAI

# %%
client=OpenAI(api_key='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')

# %%
os.environ
# Out:
# environ{'SHELL': '/bin/bash',
#         'NUGET_XMLDOC_MODE': 'skip',
#         'COLORTERM': 'truecolor',
#         'CLOUDENV_ENVIRONMENT_ID': 'fbfc5a74-41cb-49ac-99c3-05dbe557d91e',
#         'NVM_INC': '/usr/local/share/nvm/versions/node/v20.17.0/include/node',
#         'TERM_PROGRAM_VERSION': '1.94.2',
#         'GITHUB_USER': 'tpor31',
#         'CONDA_EXE': '/opt/conda/bin/conda',
#         '_CE_M': '',
#         'rvm_prefix': '/usr/local',
#         'CODESPACE_NAME': 'literate-eureka-97994wpvj5gcpjv4',
#         'HOSTNAME': 'codespaces-43c6ff',
#         'JAVA_ROOT': '/home/codespace/java',
#         'JAVA_HOME': '/usr/local/sdkman/candidates/java/current',
#         'DOTNET_ROOT': '/usr/share/dotnet',
#         'CODESPACES': 'true',
#         'PYTHON_ROOT': '/home/codespace/.python',
#         'GRADLE_HOME': '/usr/local/sdkman/candidates/gradle/current',
#         'NVS_DIR': '/usr/local/nvs',
#         'NVS_OS': 'linux',
#         'DOTNET_SKIP_FIRST_TIME_EXPERIENCE': '1',
# ...

# %%
response = client.chat.completions.create(
    model='gpt-4o-mini',
    messages=[{"role":"user", "content":"is it too late to join the course?"}]

    
)
